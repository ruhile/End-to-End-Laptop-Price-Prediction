# %% [markdown]
# # 📅 Week 18 – Day 1: Data Understanding
#
# This notebook covers initial data loading, basic exploration, statistical summaries, missing value check, duplicate removal, target variable visualization, and saving the initial processed dataset.

# %% [markdown]
# ## 1️⃣ Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 2️⃣ Load Dataset

# %%
# Load dataset with path fallback
path = "../data/raw/laptops.csv"
if not os.path.exists(path):
    path = "data/raw/laptops.csv"
    
df = pd.read_csv(path)
print(f"Loaded dataset from: {path}")

# %% [markdown]
# ## 3️⃣ Display First 5 Rows
#
# **Questions to ask yourself:**
# - What is each row? (A laptop model with specifications and price)
# - What is each column? (Attributes like Brand, CPU, RAM, Storage, Screen size, GPU, Price)
# - Which column looks like our target? (`Final Price` / `Price`)

# %%
df.head()

# %% [markdown]
# ## 4️⃣ Dataset Shape

# %%
print("Dataset Shape:", df.shape)

# %% [markdown]
# ## 5️⃣ Column Names

# %%
df.columns

# %% [markdown]
# ## 6️⃣ Dataset Information

# %%
df.info()

# %% [markdown]
# ## 7️⃣ Statistical Summary (Numerical Columns)

# %%
df.describe()

# %% [markdown]
# ## 8️⃣ Statistical Summary Including Categorical Columns

# %%
df.describe(include='all')

# %% [markdown]
# ## 9️⃣ Check Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# ## 🔟 Duplicate Rows

# %%
print("Duplicate rows:", df.duplicated().sum())
if df.duplicated().sum() > 0:
    df = df.drop_duplicates()
    print("Duplicates removed. New shape:", df.shape)

# %% [markdown]
# ## 1️⃣1️⃣ Check Data Types

# %%
df.dtypes

# %% [markdown]
# ## 1️⃣2️⃣ Target Variable Analysis

# %%
target_col = 'Final Price' if 'Final Price' in df.columns else 'Price'
print(df[target_col].describe())

plt.figure(figsize=(8,5))
sns.histplot(df[target_col], bins=30, kde=True)
plt.title(f"{target_col} Distribution")
plt.xlabel(target_col)
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## 1️⃣3️⃣ Correlation Matrix

# %%
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 1️⃣4️⃣ Save Clean/Processed Copy

# %%
out_path = "../data/processed/laptops_day1.csv"
if not os.path.exists("../data/processed"):
    out_path = "data/processed/laptops_day1.csv"

df.to_csv(out_path, index=False)
print(f"Saved processed file to {out_path}")
